# %%
import pandas as pd

# %%
# %matplotlib notebook

# %%
from rekko.coordinator import Coordinator, ExperimentCoordinator, Path

# %%
ec = ExperimentCoordinator()

# %%
runs = ec.references.join('runs.csv').load()

# %%
runs_pruning = ec.references.join('runs_pruning.csv').load()

# %%
import seaborn as sns

# %%
sns.heatmap(pd.pivot(runs, index = 'alpha', columns='beta',values='MNAP_at_20_test'), annot=True, fmt='.4g');
# Out:
# <img src="data:image/png;base64,..." width="886">

# %%
sns.set()

# %%
sns.relplot(data=runs_pruning, x='max_len', y='MNAP_at_20_test', kind="line");
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
runs_pruning[runs_pruning.max_len==25].MNAP_at_20_test
# Out:
# 2    0.040312
# Name: MNAP_at_20_test, dtype: float64

# %%
df = pd.DataFrame([[1,2,3],[3,4,5]])
